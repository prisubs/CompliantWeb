# %%
import pandas as pd

# %%
nyse = pd.read_csv("c1.csv")
nyse.head()
# Out:
#   Symbol                                    Name  LastSale MarketCap  IPOyear  \
# 0     YI                               111, Inc.    3.9000  $318.47M   2018.0
# 1    PIH  1347 Property Insurance Holdings, Inc.    5.0500   $30.36M   2014.0
# 2  PIHPP  1347 Property Insurance Holdings, Inc.   25.5792   $17.91M      NaN
# 3   TURN                180 Degree Capital Corp.    1.9600      $61M      NaN
# 4   FLWS                 1-800 FLOWERS.COM, Inc.   19.5800    $1.26B   1999.0
#
#               Sector                    industry  \
# 0        Health Care    Medical/Nursing Services
# 1            Finance  Property-Casualty Insurers
# 2            Finance  Property-Casualty Insurers
# 3            Finance  Finance/Investors Services
# 4  Consumer Services      Other Specialty Stores
#
#                          Summary Quote  Unnamed: 8
# 0     https://www.nasdaq.com/symbol/yi         NaN
# 1    https://www.nasdaq.com/symbol/pih         NaN
# ...

# %%
nasdaq = pd.read_csv("c2.csv")
nasdaq.head()
# Out:
#   Symbol                    Name  LastSale MarketCap  IPOyear  \
# 0    DDD  3D Systems Corporation      9.02    $1.05B      NaN
# 1    MMM              3M Company    174.72  $100.51B      NaN
# 2   WBAI         500.com Limited     11.17  $478.23M   2013.0
# 3   WUBA             58.com Inc.     56.38    $8.38B   2013.0
# 4   EGHT                 8x8 Inc     24.17     $2.4B      NaN
#
#               Sector                                         industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services
#
#                         Summary Quote  Unnamed: 8
# 0   https://www.nasdaq.com/symbol/ddd         NaN
# 1   https://www.nasdaq.com/symbol/mmm         NaN
# ...

# %%
amex = pd.read_csv("c3.csv")
amex.head()
# Out:
#   Symbol                                               Name  LastSale  \
# 0   XXII                            22nd Century Group, Inc      1.59
# 1    FAX              Aberdeen Asia-Pacific Income Fund Inc      4.22
# 2    IAF                 Aberdeen Australia Equity Fund Inc      5.47
# 3    AEF  Aberdeen Emerging Markets Equity Income Fund, ...      7.28
# 4    FCO                  Aberdeen Global Income Fund, Inc.      8.62
#
#   MarketCap  IPOyear                 Sector               industry  \
# 0  $198.21M      NaN  Consumer Non-Durables  Farming/Seeds/Milling
# 1    $1.05B   1986.0                    NaN                    NaN
# 2   $124.4M      NaN                    NaN                    NaN
# 3  $369.47M      NaN                    NaN                    NaN
# 4   $75.21M   1992.0                    NaN                    NaN
#
#                         Summary Quote  Unnamed: 8
# 0  https://www.nasdaq.com/symbol/xxii         NaN
# ...

# %%
df = pd.concat([nasdaq, nyse])
df.head()
# Out:
#   Symbol                    Name  LastSale MarketCap  IPOyear  \
# 0    DDD  3D Systems Corporation      9.02    $1.05B      NaN
# 1    MMM              3M Company    174.72  $100.51B      NaN
# 2   WBAI         500.com Limited     11.17  $478.23M   2013.0
# 3   WUBA             58.com Inc.     56.38    $8.38B   2013.0
# 4   EGHT                 8x8 Inc     24.17     $2.4B      NaN
#
#               Sector                                         industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services
#
#                         Summary Quote  Unnamed: 8
# 0   https://www.nasdaq.com/symbol/ddd         NaN
# 1   https://www.nasdaq.com/symbol/mmm         NaN
# ...

# %%
df.shape
# Out:
# (6634, 9)

# %%
df = df.rename({"Symbol": "Ticker"}, axis=1)
df = df[["Ticker", "Sector", "industry", "Name"]]
df.head()
# Out:
#   Ticker             Sector                                         industry  \
# 0    DDD         Technology          Computer Software: Prepackaged Software
# 1    MMM        Health Care                       Medical/Dental Instruments
# 2   WBAI  Consumer Services            Services-Misc. Amusement & Recreation
# 3   WUBA         Technology  Computer Software: Programming, Data Processing
# 4   EGHT         Technology                                     EDP Services
#
#                      Name
# 0  3D Systems Corporation
# 1              3M Company
# 2         500.com Limited
# 3             58.com Inc.
# 4                 8x8 Inc

# %%
df.to_csv("ticker_translate.csv")

# %%
pd.read_csv("ticker_translate.csv").head()
# Out:
#    Unnamed: 0 Ticker             Sector  \
# 0           0    DDD         Technology
# 1           1    MMM        Health Care
# 2           2   WBAI  Consumer Services
# 3           3   WUBA         Technology
# 4           4   EGHT         Technology
#
#                                           industry                    Name
# 0          Computer Software: Prepackaged Software  3D Systems Corporation
# 1                       Medical/Dental Instruments              3M Company
# 2            Services-Misc. Amusement & Recreation         500.com Limited
# 3  Computer Software: Programming, Data Processing             58.com Inc.
# 4                                     EDP Services                 8x8 Inc
