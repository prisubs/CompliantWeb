# %%
import pandas as pd
import numpy as np
import datetime
from tiingo import TiingoClient
from sklearn.impute import SimpleImputer
from sklearn import preprocessing
import indicoio
from textblob import TextBlob
from sklearn import linear_model
import _pickle as cPickle

# %%
# feature functions
def impute(X):
    imp = SimpleImputer(missing_values=np.nan, strategy='mean')
    imp = imp.fit(X)
    X = imp.transform(X)
    return X

def good_bag(string_vector):
    bag = pd.read_csv("data/sentiment_word_list.csv")
    good_bag = bag["good"].dropna().apply(str.lower).to_list()
    good_count = 0
    count = 0
    ttl_length = 0
    string_vector = ' '.join(string_vector)
    for word in good_bag:
        for word2 in string_vector.split():
            ttl_length = ttl_length + 1
            if (word.lower() == word2.lower()):
                count = count + 1
    return count/ttl_length


def bad_bag(string_vector):
    bag = pd.read_csv("data/sentiment_word_list.csv")
    bad_bag = bag["bad"].apply(str.lower).to_list()
    bad_count = 0
    good_count = 0
    count = 0
    ttl_length = 0
    string_vector = ' '.join(string_vector)
    for word in bad_bag:
        for word2 in string_vector.split():
            ttl_length = ttl_length + 1
            if (word.lower() == word2.lower()):
                count = count + 1
    return count/ttl_length


def aggregate_jsons(json_list):
    result = []
    for json in json_list:
        headline = json["title"]
        desc = json["description"]
        x = headline + " " + desc
        result.append(x)
    return result

# %%
# takes in a model object
# writes it out to a PKL file
def pickle_up(model, filepath):
    # save the classifier
    with open(filepath, 'wb') as fid:
        cPickle.dump(model, fid) 
    print("saved model to {0}".format(filepath))
        
def pickle_down(filepath):
    # load it again
    with open(filepath, 'rb') as fid:
        model_loaded = cPickle.load(fid)
    return model_loaded

# %%
def pipeline(ticker, date):
    six_days = lambda start_date: start_date + datetime.timedelta(days=6)
    remove_time = lambda dt: dt[0:10]
    
    start_date = pd.to_datetime(pd.Series([date]), infer_datetime_format = True)
    end_date = start_date.apply(six_days).apply(str)[0]
    start_date = start_date.apply(str).apply(remove_time)[0]
    
    client = TiingoClient({"api_key": "a265fc4a1013923f970d16e7348195074e97fcb0"})
    prices = client.get_ticker_price(ticker, fmt='object', startDate=start_date, endDate=end_date, frequency='daily')
    open_price = prices[0].open
    close_price = prices[-1].close
    
     # add json 
    client = TiingoClient({"api_key": "a265fc4a1013923f970d16e7348195074e97fcb0"})
    query_ticker = lambda t, s, e: client.get_news(tickers=[t], startDate=s, endDate=e)
    json = query_ticker(ticker, start_date, end_date)

    # create corpus
    corpus = aggregate_jsons(json)
    vectorized = corpus
    combinatric = lambda l: ''.join(l)
    corpus = combinatric(vectorized)
    
    indicoio.config.api_key = "04878c9a5bb99aaf8a8ccdd65954442a"

    # add sentiment
    mean = lambda listy: sum(listy)/len(listy)
    sentiment = (lambda orig: TextBlob(orig).sentiment.polarity) (corpus)
    sentiment_test = mean((lambda orig: [TextBlob(o).sentiment.polarity for o in orig])(vectorized))
    indico_sentiment = (lambda text: indicoio.sentiment_hq(text))(corpus)

    # add bag of words featurization
    badbag = bad_bag(vectorized)
    goodbag = good_bag(vectorized)
    
    # add last week's data
    start_last = pd.to_datetime(pd.Series([start_date])).apply(lambda start_date: start_date - datetime.timedelta(days=6))
    start_last = remove_time(str(start_last.values[0]))
    end_last = start_date
    lastweek = client.get_ticker_price(ticker, fmt='object', startDate=start_last, endDate=end_last, frequency='daily')
    lastweek = lastweek[0].close
    
    # add the delta - up or down
    tri_delt = close_price - open_price
    if tri_delt > 0:
        delta = 1
    else:
        delta = 0

    df = pd.DataFrame(
        {
            "Start": pd.Series([start_date]),
            "End": pd.Series([end_date]),
            "sentiment": pd.Series([sentiment]),
            "sentiment_test": pd.Series([sentiment_test]),
            "indico_sentiment": pd.Series([indico_sentiment]),
            "bad_bag": pd.Series([badbag]),
            "good_bag": pd.Series([goodbag]),
            "lastweek": pd.Series([lastweek]),
            "delta": pd.Series([delta])
        }
    )
    
    return df

# %%
def multi_row_pipeline(dates, ticker):
    rows = []
    for date in dates:
        row = pipeline(ticker, date)
        rows.append(row)
    df = pd.concat(rows)
    return df

# %%
def run_model(df, model_path):
    model = pickle_down(model_path)
    X_test = df[["indico_sentiment", "sentiment", "sentiment_test", "bad_bag", "good_bag"]]
    Y_test = df["delta"]
    
    X_test = impute(X_test)
    scaler = preprocessing.StandardScaler().fit(X_test)
    X_test = scaler.transform(X_test)         
    Y_predicted = model.predict(X_test)
    accuracy = (np.sum(Y_predicted) / np.sum(Y_test)) * 100
    print("predicted with {0}% accuracy".format(accuracy))
    return pd.DataFrame({"actual": Y_test, "predicted": Y_predicted})

# takes in a dataframe, runs logistic regression
def generate_model(d):
    training_X_cols = ["indico_sentiment", "sentiment", 
                       "sentiment_test", "bad_bag", "good_bag"]
    training_Y_col = "delta"

    # Train on ALL rows
    X_train = impute(d[training_X_cols])
    Y_train = d[training_Y_col]

    scaler = preprocessing.StandardScaler().fit(X_train)
    X_train = scaler.transform(X_train)

    model = linear_model.LogisticRegression(solver="lbfgs")
    model.fit(X_train, Y_train)
    
    return model

# %% [markdown]
# ## training + saving logistic regression model

# %%
tickers = ["aapl", "amzn", "baba", "crm", "fb", "googl", "msft", "nflx", "tsla", "wmt"]
start_dates = pd.read_csv("data/dates.csv")["0"].tolist()

# %%
master_df_set = []
for ticker in tickers:
    for date in start_dates:
        row = pipeline(ticker, date)
        master_df_set.append(row)
        print("finished date {0} for ticker {1}".format(date, ticker))
        print("S I C K O M O D E")
# Out:
# finished date 2018-12-24 for ticker aapl
# S I C K O M O D E
# finished date 2018-12-31 for ticker aapl
# S I C K O M O D E
# finished date 2019-01-07 for ticker aapl
# S I C K O M O D E
# finished date 2019-01-14 for ticker aapl
# S I C K O M O D E
# finished date 2019-01-21 for ticker aapl
# S I C K O M O D E
# finished date 2019-01-28 for ticker aapl
# S I C K O M O D E
# finished date 2019-02-04 for ticker aapl
# S I C K O M O D E
# finished date 2019-02-11 for ticker aapl
# S I C K O M O D E
# finished date 2019-02-18 for ticker aapl
# S I C K O M O D E
# finished date 2019-02-25 for ticker aapl
# S I C K O M O D E
# finished date 2019-03-04 for ticker aapl
# S I C K O M O D E
# finished date 2019-03-11 for ticker aapl
# S I C K O M O D E
# finished date 2019-03-18 for ticker aapl
# S I C K O M O D E
# finished date 2019-03-25 for ticker aapl
# S I C K O M O D E
# finished date 2019-04-01 for ticker aapl
# S I C K O M O D E
# finished date 2019-04-08 for ticker aapl
# S I C K O M O D E
# finished date 2019-04-15 for ticker aapl
# S I C K O M O D E
# finished date 2019-04-22 for ticker aapl
# S I C K O M O D E
# finished date 2019-04-29 for ticker aapl
# S I C K O M O D E
# finished date 2019-05-06 for ticker aapl
# S I C K O M O D E
# finished date 2019-05-13 for ticker aapl
# S I C K O M O D E
# finished date 2019-05-20 for ticker aapl
# S I C K O M O D E
# finished date 2019-05-27 for ticker aapl
# S I C K O M O D E
# finished date 2019-06-03 for ticker aapl
# S I C K O M O D E
# finished date 2019-06-10 for ticker aapl
# S I C K O M O D E
# finished date 2019-06-17 for ticker aapl
# S I C K O M O D E
# finished date 2019-06-24 for ticker aapl
# S I C K O M O D E
# finished date 2018-12-24 for ticker amzn
# S I C K O M O D E
# finished date 2018-12-31 for ticker amzn
# S I C K O M O D E
# finished date 2019-01-07 for ticker amzn
# S I C K O M O D E
# finished date 2019-01-14 for ticker amzn
# S I C K O M O D E
# finished date 2019-01-21 for ticker amzn
# S I C K O M O D E
# finished date 2019-01-28 for ticker amzn
# S I C K O M O D E
# finished date 2019-02-04 for ticker amzn
# S I C K O M O D E
# finished date 2019-02-11 for ticker amzn
# S I C K O M O D E
# finished date 2019-02-18 for ticker amzn
# S I C K O M O D E
# finished date 2019-02-25 for ticker amzn
# S I C K O M O D E
# finished date 2019-03-04 for ticker amzn
# S I C K O M O D E
# finished date 2019-03-11 for ticker amzn
# S I C K O M O D E
# finished date 2019-03-18 for ticker amzn
# S I C K O M O D E
# finished date 2019-03-25 for ticker amzn
# S I C K O M O D E
# finished date 2019-04-01 for ticker amzn
# S I C K O M O D E
# finished date 2019-04-08 for ticker amzn
# S I C K O M O D E
# finished date 2019-04-15 for ticker amzn
# S I C K O M O D E
# finished date 2019-04-22 for ticker amzn
# S I C K O M O D E
# finished date 2019-04-29 for ticker amzn
# S I C K O M O D E
# finished date 2019-05-06 for ticker amzn
# S I C K O M O D E
# finished date 2019-05-13 for ticker amzn
# S I C K O M O D E
# finished date 2019-05-20 for ticker amzn
# S I C K O M O D E
# finished date 2019-05-27 for ticker amzn
# S I C K O M O D E
# finished date 2019-06-03 for ticker amzn
# S I C K O M O D E
# finished date 2019-06-10 for ticker amzn
# S I C K O M O D E
# finished date 2019-06-17 for ticker amzn
# S I C K O M O D E
# finished date 2019-06-24 for ticker amzn
# S I C K O M O D E
# finished date 2018-12-24 for ticker baba
# S I C K O M O D E
# finished date 2018-12-31 for ticker baba
# S I C K O M O D E
# finished date 2019-01-07 for ticker baba
# S I C K O M O D E
# finished date 2019-01-14 for ticker baba
# S I C K O M O D E
# finished date 2019-01-21 for ticker baba
# S I C K O M O D E
# finished date 2019-01-28 for ticker baba
# S I C K O M O D E
# finished date 2019-02-04 for ticker baba
# S I C K O M O D E
# finished date 2019-02-11 for ticker baba
# S I C K O M O D E
# finished date 2019-02-18 for ticker baba
# S I C K O M O D E
# finished date 2019-02-25 for ticker baba
# S I C K O M O D E
# finished date 2019-03-04 for ticker baba
# S I C K O M O D E
# finished date 2019-03-11 for ticker baba
# S I C K O M O D E
# finished date 2019-03-18 for ticker baba
# S I C K O M O D E
# finished date 2019-03-25 for ticker baba
# S I C K O M O D E
# finished date 2019-04-01 for ticker baba
# S I C K O M O D E
# finished date 2019-04-08 for ticker baba
# S I C K O M O D E
# finished date 2019-04-15 for ticker baba
# S I C K O M O D E
# finished date 2019-04-22 for ticker baba
# S I C K O M O D E
# finished date 2019-04-29 for ticker baba
# S I C K O M O D E
# finished date 2019-05-06 for ticker baba
# S I C K O M O D E
# finished date 2019-05-13 for ticker baba
# S I C K O M O D E
# finished date 2019-05-20 for ticker baba
# S I C K O M O D E
# finished date 2019-05-27 for ticker baba
# S I C K O M O D E
# finished date 2019-06-03 for ticker baba
# S I C K O M O D E
# finished date 2019-06-10 for ticker baba
# S I C K O M O D E
# finished date 2019-06-17 for ticker baba
# S I C K O M O D E
# finished date 2019-06-24 for ticker baba
# S I C K O M O D E
# finished date 2018-12-24 for ticker crm
# S I C K O M O D E
# finished date 2018-12-31 for ticker crm
# S I C K O M O D E
# finished date 2019-01-07 for ticker crm
# S I C K O M O D E
# finished date 2019-01-14 for ticker crm
# S I C K O M O D E
# finished date 2019-01-21 for ticker crm
# S I C K O M O D E
# finished date 2019-01-28 for ticker crm
# S I C K O M O D E
# finished date 2019-02-04 for ticker crm
# S I C K O M O D E
# finished date 2019-02-11 for ticker crm
# S I C K O M O D E
# finished date 2019-02-18 for ticker crm
# S I C K O M O D E
# finished date 2019-02-25 for ticker crm
# S I C K O M O D E
# finished date 2019-03-04 for ticker crm
# S I C K O M O D E
# finished date 2019-03-11 for ticker crm
# S I C K O M O D E
# finished date 2019-03-18 for ticker crm
# S I C K O M O D E
# finished date 2019-03-25 for ticker crm
# S I C K O M O D E
# finished date 2019-04-01 for ticker crm
# S I C K O M O D E
# finished date 2019-04-08 for ticker crm
# S I C K O M O D E
# finished date 2019-04-15 for ticker crm
# S I C K O M O D E
# finished date 2019-04-22 for ticker crm
# S I C K O M O D E
# finished date 2019-04-29 for ticker crm
# S I C K O M O D E
# finished date 2019-05-06 for ticker crm
# S I C K O M O D E
# finished date 2019-05-13 for ticker crm
# S I C K O M O D E
# finished date 2019-05-20 for ticker crm
# S I C K O M O D E
# finished date 2019-05-27 for ticker crm
# S I C K O M O D E
# finished date 2019-06-03 for ticker crm
# S I C K O M O D E
# finished date 2019-06-10 for ticker crm
# S I C K O M O D E
# finished date 2019-06-17 for ticker crm
# S I C K O M O D E
# finished date 2019-06-24 for ticker crm
# S I C K O M O D E
# finished date 2018-12-24 for ticker fb
# S I C K O M O D E
# finished date 2018-12-31 for ticker fb
# S I C K O M O D E
# finished date 2019-01-07 for ticker fb
# S I C K O M O D E
# finished date 2019-01-14 for ticker fb
# S I C K O M O D E
# finished date 2019-01-21 for ticker fb
# S I C K O M O D E
# finished date 2019-01-28 for ticker fb
# S I C K O M O D E
# finished date 2019-02-04 for ticker fb
# S I C K O M O D E
# finished date 2019-02-11 for ticker fb
# S I C K O M O D E
# finished date 2019-02-18 for ticker fb
# S I C K O M O D E
# finished date 2019-02-25 for ticker fb
# S I C K O M O D E
# finished date 2019-03-04 for ticker fb
# S I C K O M O D E
# finished date 2019-03-11 for ticker fb
# S I C K O M O D E
# finished date 2019-03-18 for ticker fb
# S I C K O M O D E
# finished date 2019-03-25 for ticker fb
# S I C K O M O D E
# finished date 2019-04-01 for ticker fb
# S I C K O M O D E
# finished date 2019-04-08 for ticker fb
# S I C K O M O D E
# finished date 2019-04-15 for ticker fb
# S I C K O M O D E
# finished date 2019-04-22 for ticker fb
# S I C K O M O D E
# finished date 2019-04-29 for ticker fb
# S I C K O M O D E
# finished date 2019-05-06 for ticker fb
# S I C K O M O D E
# finished date 2019-05-13 for ticker fb
# S I C K O M O D E
# finished date 2019-05-20 for ticker fb
# S I C K O M O D E
# finished date 2019-05-27 for ticker fb
# S I C K O M O D E
# finished date 2019-06-03 for ticker fb
# S I C K O M O D E
# finished date 2019-06-10 for ticker fb
# S I C K O M O D E
# finished date 2019-06-17 for ticker fb
# S I C K O M O D E
# finished date 2019-06-24 for ticker fb
# S I C K O M O D E
# finished date 2018-12-24 for ticker googl
# S I C K O M O D E
# finished date 2018-12-31 for ticker googl
# S I C K O M O D E
# finished date 2019-01-07 for ticker googl
# S I C K O M O D E
# finished date 2019-01-14 for ticker googl
# S I C K O M O D E
# finished date 2019-01-21 for ticker googl
# S I C K O M O D E
# finished date 2019-01-28 for ticker googl
# S I C K O M O D E
# finished date 2019-02-04 for ticker googl
# S I C K O M O D E
# finished date 2019-02-11 for ticker googl
# S I C K O M O D E
# finished date 2019-02-18 for ticker googl
# S I C K O M O D E
# finished date 2019-02-25 for ticker googl
# S I C K O M O D E
# finished date 2019-03-04 for ticker googl
# S I C K O M O D E
# finished date 2019-03-11 for ticker googl
# S I C K O M O D E
# finished date 2019-03-18 for ticker googl
# S I C K O M O D E
# finished date 2019-03-25 for ticker googl
# S I C K O M O D E
# finished date 2019-04-01 for ticker googl
# S I C K O M O D E
# finished date 2019-04-08 for ticker googl
# S I C K O M O D E
# finished date 2019-04-15 for ticker googl
# S I C K O M O D E
# finished date 2019-04-22 for ticker googl
# S I C K O M O D E
# finished date 2019-04-29 for ticker googl
# S I C K O M O D E
# finished date 2019-05-06 for ticker googl
# S I C K O M O D E
# finished date 2019-05-13 for ticker googl
# S I C K O M O D E
# finished date 2019-05-20 for ticker googl
# S I C K O M O D E
# finished date 2019-05-27 for ticker googl
# S I C K O M O D E
# finished date 2019-06-03 for ticker googl
# S I C K O M O D E
# finished date 2019-06-10 for ticker googl
# S I C K O M O D E
# finished date 2019-06-17 for ticker googl
# S I C K O M O D E
# finished date 2019-06-24 for ticker googl
# S I C K O M O D E
# finished date 2018-12-24 for ticker msft
# S I C K O M O D E
# finished date 2018-12-31 for ticker msft
# S I C K O M O D E
# finished date 2019-01-07 for ticker msft
# S I C K O M O D E
# finished date 2019-01-14 for ticker msft
# S I C K O M O D E
# finished date 2019-01-21 for ticker msft
# S I C K O M O D E
# finished date 2019-01-28 for ticker msft
# S I C K O M O D E
# finished date 2019-02-04 for ticker msft
# S I C K O M O D E
# finished date 2019-02-11 for ticker msft
# S I C K O M O D E
# finished date 2019-02-18 for ticker msft
# S I C K O M O D E
# finished date 2019-02-25 for ticker msft
# S I C K O M O D E
# finished date 2019-03-04 for ticker msft
# S I C K O M O D E
# finished date 2019-03-11 for ticker msft
# S I C K O M O D E
# finished date 2019-03-18 for ticker msft
# S I C K O M O D E
# finished date 2019-03-25 for ticker msft
# S I C K O M O D E
# finished date 2019-04-01 for ticker msft
# S I C K O M O D E
# finished date 2019-04-08 for ticker msft
# S I C K O M O D E
# finished date 2019-04-15 for ticker msft
# S I C K O M O D E
# finished date 2019-04-22 for ticker msft
# S I C K O M O D E
# finished date 2019-04-29 for ticker msft
# S I C K O M O D E
# finished date 2019-05-06 for ticker msft
# S I C K O M O D E
# finished date 2019-05-13 for ticker msft
# S I C K O M O D E
# finished date 2019-05-20 for ticker msft
# S I C K O M O D E
# finished date 2019-05-27 for ticker msft
# S I C K O M O D E
# finished date 2019-06-03 for ticker msft
# S I C K O M O D E
# finished date 2019-06-10 for ticker msft
# S I C K O M O D E
# finished date 2019-06-17 for ticker msft
# S I C K O M O D E
# finished date 2019-06-24 for ticker msft
# S I C K O M O D E
# finished date 2018-12-24 for ticker nflx
# S I C K O M O D E
# finished date 2018-12-31 for ticker nflx
# S I C K O M O D E
# finished date 2019-01-07 for ticker nflx
# S I C K O M O D E
# finished date 2019-01-14 for ticker nflx
# S I C K O M O D E
# finished date 2019-01-21 for ticker nflx
# S I C K O M O D E
# finished date 2019-01-28 for ticker nflx
# S I C K O M O D E
# finished date 2019-02-04 for ticker nflx
# S I C K O M O D E
# finished date 2019-02-11 for ticker nflx
# S I C K O M O D E
# finished date 2019-02-18 for ticker nflx
# S I C K O M O D E
# finished date 2019-02-25 for ticker nflx
# S I C K O M O D E
# finished date 2019-03-04 for ticker nflx
# S I C K O M O D E
# finished date 2019-03-11 for ticker nflx
# S I C K O M O D E
# finished date 2019-03-18 for ticker nflx
# S I C K O M O D E
# finished date 2019-03-25 for ticker nflx
# S I C K O M O D E
# finished date 2019-04-01 for ticker nflx
# S I C K O M O D E
# finished date 2019-04-08 for ticker nflx
# S I C K O M O D E
# finished date 2019-04-15 for ticker nflx
# S I C K O M O D E
# finished date 2019-04-22 for ticker nflx
# S I C K O M O D E
# finished date 2019-04-29 for ticker nflx
# S I C K O M O D E
# finished date 2019-05-06 for ticker nflx
# S I C K O M O D E
# finished date 2019-05-13 for ticker nflx
# S I C K O M O D E
# finished date 2019-05-20 for ticker nflx
# S I C K O M O D E
# finished date 2019-05-27 for ticker nflx
# S I C K O M O D E
# finished date 2019-06-03 for ticker nflx
# S I C K O M O D E
# finished date 2019-06-10 for ticker nflx
# S I C K O M O D E
# finished date 2019-06-17 for ticker nflx
# S I C K O M O D E
# finished date 2019-06-24 for ticker nflx
# S I C K O M O D E
# finished date 2018-12-24 for ticker tsla
# S I C K O M O D E
# finished date 2018-12-31 for ticker tsla
# S I C K O M O D E
# finished date 2019-01-07 for ticker tsla
# S I C K O M O D E
# finished date 2019-01-14 for ticker tsla
# S I C K O M O D E
# finished date 2019-01-21 for ticker tsla
# S I C K O M O D E
# finished date 2019-01-28 for ticker tsla
# S I C K O M O D E
# finished date 2019-02-04 for ticker tsla
# S I C K O M O D E
# finished date 2019-02-11 for ticker tsla
# S I C K O M O D E
# finished date 2019-02-18 for ticker tsla
# S I C K O M O D E
# finished date 2019-02-25 for ticker tsla
# S I C K O M O D E
# finished date 2019-03-04 for ticker tsla
# S I C K O M O D E
# finished date 2019-03-11 for ticker tsla
# S I C K O M O D E
# finished date 2019-03-18 for ticker tsla
# S I C K O M O D E
# finished date 2019-03-25 for ticker tsla
# S I C K O M O D E
# finished date 2019-04-01 for ticker tsla
# S I C K O M O D E
# finished date 2019-04-08 for ticker tsla
# S I C K O M O D E
# finished date 2019-04-15 for ticker tsla
# S I C K O M O D E
# finished date 2019-04-22 for ticker tsla
# S I C K O M O D E
# finished date 2019-04-29 for ticker tsla
# S I C K O M O D E
# finished date 2019-05-06 for ticker tsla
# S I C K O M O D E
# finished date 2019-05-13 for ticker tsla
# S I C K O M O D E
# finished date 2019-05-20 for ticker tsla
# S I C K O M O D E
# finished date 2019-05-27 for ticker tsla
# S I C K O M O D E
# finished date 2019-06-03 for ticker tsla
# S I C K O M O D E
# finished date 2019-06-10 for ticker tsla
# S I C K O M O D E
# finished date 2019-06-17 for ticker tsla
# S I C K O M O D E
# finished date 2019-06-24 for ticker tsla
# S I C K O M O D E
# finished date 2018-12-24 for ticker wmt
# S I C K O M O D E
# finished date 2018-12-31 for ticker wmt
# S I C K O M O D E
# finished date 2019-01-07 for ticker wmt
# S I C K O M O D E
# finished date 2019-01-14 for ticker wmt
# S I C K O M O D E
# finished date 2019-01-21 for ticker wmt
# S I C K O M O D E
# finished date 2019-01-28 for ticker wmt
# S I C K O M O D E
# finished date 2019-02-04 for ticker wmt
# S I C K O M O D E
# finished date 2019-02-11 for ticker wmt
# S I C K O M O D E
# finished date 2019-02-18 for ticker wmt
# S I C K O M O D E
# finished date 2019-02-25 for ticker wmt
# S I C K O M O D E
# finished date 2019-03-04 for ticker wmt
# S I C K O M O D E
# finished date 2019-03-11 for ticker wmt
# S I C K O M O D E
# finished date 2019-03-18 for ticker wmt
# S I C K O M O D E
# finished date 2019-03-25 for ticker wmt
# S I C K O M O D E
# finished date 2019-04-01 for ticker wmt
# S I C K O M O D E
# finished date 2019-04-08 for ticker wmt
# S I C K O M O D E
# finished date 2019-04-15 for ticker wmt
# S I C K O M O D E
# finished date 2019-04-22 for ticker wmt
# S I C K O M O D E
# finished date 2019-04-29 for ticker wmt
# S I C K O M O D E
# finished date 2019-05-06 for ticker wmt
# S I C K O M O D E
# finished date 2019-05-13 for ticker wmt
# S I C K O M O D E
# finished date 2019-05-20 for ticker wmt
# S I C K O M O D E
# finished date 2019-05-27 for ticker wmt
# S I C K O M O D E
# finished date 2019-06-03 for ticker wmt
# S I C K O M O D E
# finished date 2019-06-10 for ticker wmt
# S I C K O M O D E
# finished date 2019-06-17 for ticker wmt
# S I C K O M O D E
# finished date 2019-06-24 for ticker wmt
# S I C K O M O D E

# %%
df = pd.concat(master_df_set)
df.to_csv("data/240_rows.csv")
model = generate_model(df)
pickle_up(model, "data/logistic.pkl")
# Out:
# saved model to data/logistic.pkl

# %%
model = pickle_down("data/logistic.pkl")

# %%
dates_to_predict = ["2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05"]
df = multi_row_pipeline(dates_to_predict, "fb")
run_model(df, "data/logistic.pkl")
# Out:
# predicted with 100.0% accuracy
#    actual  predicted
# 0       1          1
# 0       1          1
# 0       1          1
# 0       1          1
# 0       1          1

# %%
pd.read_csv("data/240_rows.csv")
# Out:
#      Unnamed: 0       Start                  End  sentiment  sentiment_test  \
# 0             0  2018-12-24  2018-12-30 00:00:00   0.115305        0.095800
# 1             0  2018-12-31  2019-01-06 00:00:00   0.115305        0.095800
# 2             0  2019-01-07  2019-01-13 00:00:00   0.115305        0.095800
# 3             0  2019-01-14  2019-01-20 00:00:00   0.115305        0.095800
# 4             0  2019-01-21  2019-01-27 00:00:00   0.115305        0.095800
# 5             0  2019-01-28  2019-02-03 00:00:00   0.115305        0.095800
# 6             0  2019-02-04  2019-02-10 00:00:00   0.115305        0.095800
# 7             0  2019-02-11  2019-02-17 00:00:00   0.115305        0.095800
# 8             0  2019-02-18  2019-02-24 00:00:00   0.115305        0.095800
# 9             0  2019-02-25  2019-03-03 00:00:00   0.115305        0.095800
# 10            0  2019-03-04  2019-03-10 00:00:00   0.115305        0.095800
# 11            0  2019-03-11  2019-03-17 00:00:00   0.115305        0.095800
# 12            0  2019-03-18  2019-03-24 00:00:00   0.115305        0.095800
# 13            0  2019-03-25  2019-03-31 00:00:00   0.115305        0.095800
# 14            0  2019-04-01  2019-04-07 00:00:00   0.115305        0.095800
# 15            0  2019-04-08  2019-04-14 00:00:00   0.132311        0.107824
# 16            0  2019-04-15  2019-04-21 00:00:00   0.112130        0.101073
# 17            0  2019-04-22  2019-04-28 00:00:00   0.114110        0.088040
# 18            0  2019-04-29  2019-05-05 00:00:00   0.104843        0.100256
# 19            0  2019-05-06  2019-05-12 00:00:00   0.098624        0.114567
# 20            0  2019-05-13  2019-05-19 00:00:00   0.074015        0.043539
# 21            0  2019-05-20  2019-05-26 00:00:00   0.062066        0.056759
# 22            0  2019-05-27  2019-06-02 00:00:00   0.160747        0.147342
# 23            0  2019-06-03  2019-06-09 00:00:00   0.131014        0.116657
# 24            0  2019-06-10  2019-06-16 00:00:00   0.035388        0.041020
# 25            0  2019-06-17  2019-06-23 00:00:00   0.128728        0.097898
# 26            0  2019-06-24  2019-06-30 00:00:00   0.150134        0.128412
# 27            0  2018-12-24  2018-12-30 00:00:00   0.146039        0.070382
# 28            0  2018-12-31  2019-01-06 00:00:00   0.149352        0.076382
# 29            0  2019-01-07  2019-01-13 00:00:00   0.149352        0.076382
# ..          ...         ...                  ...        ...             ...
# 240           0  2019-06-10  2019-06-16 00:00:00   0.121093        0.097968
# 241           0  2019-06-17  2019-06-23 00:00:00   0.115603        0.096511
# 242           0  2019-06-24  2019-06-30 00:00:00   0.108561        0.087368
# 243           0  2018-12-24  2018-12-30 00:00:00   0.130736        0.119943
# 244           0  2018-12-31  2019-01-06 00:00:00   0.130736        0.119943
# 245           0  2019-01-07  2019-01-13 00:00:00   0.130736        0.119943
# 246           0  2019-01-14  2019-01-20 00:00:00   0.130736        0.119943
# 247           0  2019-01-21  2019-01-27 00:00:00   0.130736        0.119943
# 248           0  2019-01-28  2019-02-03 00:00:00   0.130736        0.119943
# 249           0  2019-02-04  2019-02-10 00:00:00   0.130736        0.119943
# 250           0  2019-02-11  2019-02-17 00:00:00   0.130736        0.119943
# 251           0  2019-02-18  2019-02-24 00:00:00   0.130736        0.119943
# 252           0  2019-02-25  2019-03-03 00:00:00   0.130736        0.119943
# 253           0  2019-03-04  2019-03-10 00:00:00   0.130736        0.119943
# 254           0  2019-03-11  2019-03-17 00:00:00   0.130736        0.119943
# 255           0  2019-03-18  2019-03-24 00:00:00   0.130736        0.119943
# 256           0  2019-03-25  2019-03-31 00:00:00   0.130736        0.119943
# 257           0  2019-04-01  2019-04-07 00:00:00   0.130736        0.119943
# 258           0  2019-04-08  2019-04-14 00:00:00   0.119295        0.071903
# 259           0  2019-04-15  2019-04-21 00:00:00   0.107647        0.098874
# 260           0  2019-04-22  2019-04-28 00:00:00   0.091675        0.065957
# 261           0  2019-04-29  2019-05-05 00:00:00   0.148775        0.109929
# 262           0  2019-05-06  2019-05-12 00:00:00   0.085733        0.061940
# 263           0  2019-05-13  2019-05-19 00:00:00   0.088361        0.100472
# 264           0  2019-05-20  2019-05-26 00:00:00   0.161942        0.167095
# 265           0  2019-05-27  2019-06-02 00:00:00   0.105895        0.091513
# 266           0  2019-06-03  2019-06-09 00:00:00   0.130996        0.126442
# 267           0  2019-06-10  2019-06-16 00:00:00   0.131801        0.099949
# 268           0  2019-06-17  2019-06-23 00:00:00   0.174410        0.132721
# 269           0  2019-06-24  2019-06-30 00:00:00   0.131586        0.122772
#
#      indico_sentiment   bad_bag  good_bag  lastweek  delta
# 0            0.459462  0.000005  0.000023    166.07      1
# 1            0.459462  0.000005  0.000023    157.17      0
# 2            0.459462  0.000005  0.000023    157.92      1
# 3            0.459462  0.000005  0.000023    150.75      1
# 4            0.459462  0.000005  0.000023    153.07      1
# 5            0.459462  0.000005  0.000023    153.30      1
# 6            0.459462  0.000005  0.000023    154.68      1
# 7            0.459462  0.000005  0.000023    174.18      0
# 8            0.459462  0.000005  0.000023    170.89      1
# 9            0.459462  0.000005  0.000023    170.93      1
# 10           0.459462  0.000005  0.000023    174.33      0
# 11           0.459462  0.000005  0.000023    175.53      1
# 12           0.459462  0.000005  0.000023    180.91      1
# 13           0.445949  0.000005  0.000023    186.53      0
# 14           0.461088  0.000005  0.000023    186.79      1
# 15           0.837997  0.000005  0.000032    194.02      1
# 16           0.898171  0.000005  0.000030    199.50      1
# 17           0.728181  0.000007  0.000026    199.25      1
# 18           0.976274  0.000006  0.000031    207.48      1
# 19           0.635794  0.000005  0.000023    200.67      0
# 20           0.828413  0.000006  0.000026    202.86      1
# 21           0.811583  0.000006  0.000027    188.66      0
# 22           0.909634  0.000008  0.000037    186.60      0
# 23           0.957119  0.000008  0.000030    178.23      1
# 24           0.961042  0.000009  0.000020    179.64      1
# 25           0.682020  0.000005  0.000018    194.81      1
# 26           0.987321  0.000004  0.000034    198.45      0
# 27           0.966327  0.000006  0.000041   1551.48      1
# 28           0.956074  0.000006  0.000042   1470.90      1
# 29           0.956074  0.000006  0.000042   1539.13      1
# ..                ...       ...       ...       ...    ...
# 240          0.878195  0.000010  0.000025    193.60      1
# 241          0.984938  0.000007  0.000022    217.10      1
# 242          0.980891  0.000004  0.000029    224.74      1
# 243          0.962049  0.000003  0.000040     91.08      1
# 244          0.962049  0.000003  0.000040     90.41      1
# 245          0.962049  0.000003  0.000040     93.34      1
# 246          0.962049  0.000003  0.000040     95.20      1
# 247          0.953264  0.000003  0.000040     96.25      0
# 248          0.953475  0.000003  0.000040     97.49      0
# 249          0.962551  0.000003  0.000040     96.71      1
# 250          0.962551  0.000003  0.000040     95.60      1
# 251          0.962784  0.000003  0.000040     96.97      0
# 252          0.962007  0.000003  0.000040    102.20      0
# 253          0.954578  0.000003  0.000040     98.69      0
# 254          0.951882  0.000003  0.000040     98.34      1
# 255          0.952675  0.000003  0.000040     98.37      0
# 256          0.961184  0.000003  0.000040     99.85      0
# 257          0.961291  0.000003  0.000040     98.32      1
# 258          0.885418  0.000005  0.000027     96.94      1
# 259          0.925642  0.000002  0.000032     98.69      1
# 260          0.671578  0.000006  0.000024    102.93      0
# 261          0.541698  0.000003  0.000033    103.07      1
# 262          0.518669  0.000004  0.000016    102.84      1
# 263          0.976272  0.000006  0.000028    101.30      1
# 264          0.724603  0.000006  0.000062    100.29      1
# 265          0.606067  0.000005  0.000042    101.12      0
# 266          0.960759  0.000004  0.000030    102.42      1
# 267          0.671540  0.000003  0.000037    102.56      1
# 268          0.709413  0.000009  0.000031    107.94      1
# 269          0.955601  0.000006  0.000032    109.65      0
#
# [270 rows x 10 columns]
